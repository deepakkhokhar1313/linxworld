# %%
import cv2

# %%
import pandas as pd
import numpy as np

# %%
photo = cv2.imread('kriti suresh.jpg')
photo = cv2.resize(photo , (800 , 600))

# %%
photo1 = cv2.imread('ras1.jpg')
photo1 = cv2.resize(photo1 , (800 , 600))

# %%
photo = np.hstack((photo , photo1))

# %%
cv2.imshow('hi' , photo)
cv2.waitKey()
cv2.destroyAllWindows()
